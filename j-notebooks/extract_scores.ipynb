# %%
import datetime
import glob
path = "PointersAndStruct-Lab-03-28-2021-12-39-43/*/log"

due_time = datetime.datetime.strptime('Wed Mar 19 03:00:00 UTC 2021: ', '%a %b %d %H:%M:%S UTC %Y: ')

i=0
for filename in glob.glob(path):
    score=0; changes=0
    with open(filename, 'r') as f:
        partial_score=-1
        attempts = 0
        max_changes = 0
        at_time = 0
        prev_at_time = None
        prev_score=0; 
        max_change_score=0
        for line in f:
            if line.find('UTC')!=-1:
                attempts += 1
                date_time = datetime.datetime.strptime(line, '%a %b %d %H:%M:%S UTC %Y: ')
                
                if prev_at_time != None: 
                    seconds = (date_time - prev_at_time).total_seconds()
                    if seconds<1800: at_time += seconds
                    
                prev_at_time = date_time 
                if(due_time < date_time): break
            if line.find('total_score')!=-1:
                prev_score=score
                score = int(line.split()[1].split('/')[0])
                if score>partial_score: partial_score=score
                if changes > max_changes and score-prev_score > 0: 
                    max_changes= changes
                    max_change_score = score-prev_score;
            if line.find('heap.c |')!=-1:
                changes = int(line.split()[2])
                

        print(filename.split('\\')[1], "\t score:", partial_score, "\tattempts:", attempts, "\ttotal_time:",round(at_time/60))
# Out:
# Acdiel 	 score: -1 	attempts: 1 	total_time: 0
# AlexOttoVicencio 	 score: 40 	attempts: 32 	total_time: 172
# antoanais 	 score: 70 	attempts: 13 	total_time: 70
# AquilesDiosT 	 score: 70 	attempts: 75 	total_time: 204
# bryan404 	 score: 40 	attempts: 17 	total_time: 55
# CarlosR759 	 score: 60 	attempts: 37 	total_time: 132
# chk-P 	 score: 70 	attempts: 1 	total_time: 0
# DarienPacheco 	 score: 10 	attempts: 2 	total_time: 0
# DaylanStay 	 score: 50 	attempts: 19 	total_time: 74
# ebelleng 	 score: 70 	attempts: 37 	total_time: 73
# Eddgaroto 	 score: -1 	attempts: 49 	total_time: 70
# Esteban-688 	 score: -1 	attempts: 1 	total_time: 0
# eyl-lana 	 score: 70 	attempts: 85 	total_time: 193
# F3L1P30 	 score: 70 	attempts: 73 	total_time: 197
# FelipeAriasA 	 score: -1 	attempts: 1 	total_time: 0
# FelixLazcano 	 score: 20 	attempts: 2 	total_time: 0
# Idolatrine 	 score: -1 	attempts: 1 	total_time: 0
# Ivan-galaz 	 score: 20 	attempts: 18 	total_time: 44
# JeftePonce 	 score: 70 	attempts: 3 	total_time: 6
# jnachoo 	 score: 70 	attempts: 78 	total_time: 291
# JoseOlguin01 	 score: 20 	attempts: 11 	total_time: 57
# K4pocha 	 score: 70 	attempts: 12 	total_time: 27
# kevin-meza-toro 	 score: 70 	attempts: 30 	total_time: 85
# LaVolpeChalo 	 score: 70 	attempts: 142 	total_time: 311
# Leftzara 	 score: -1 	attempts: 1 	total_time: 0
# Lucas042002 	 score: 70 	attempts: 40 	total_time: 105
# MatiG2109 	 score: 20 	attempts: 3 	total_time: 0
# matilobster 	 score: 70 	attempts: 12 	total_time: 83
# melamito 	 score: 20 	attempts: 3 	total_time: 6
# Nachitzu 	 score: 70 	attempts: 58 	total_time: 166
# NathaliaTrigo 	 score: 20 	attempts: 8 	total_time: 26
# nicoacuna10 	 score: 70 	attempts: 6 	total_time: 39
# nicobrevis 	 score: 30 	attempts: 71 	total_time: 134
# Nikob1 	 score: -1 	attempts: 1 	total_time: 0
# NivekNK 	 score: 70 	attempts: 30 	total_time: 131
# OkitaDev 	 score: 70 	attempts: 188 	total_time: 321
# Pipasoo 	 score: 50 	attempts: 7 	total_time: 27
# prindoxx 	 score: 10 	attempts: 12 	total_time: 35
# ribrl 	 score: -1 	attempts: 1 	total_time: 0
# rilianx 	 score: 10 	attempts: 1 	total_time: 0
# Sashiiii 	 score: 70 	attempts: 34 	total_time: 79
# SebaVac 	 score: -1 	attempts: 1 	total_time: 0
# shyp0 	 score: 40 	attempts: 26 	total_time: 81
# Soulhae 	 score: 70 	attempts: 24 	total_time: 85
# speedysw 	 score: 70 	attempts: 58 	total_time: 206
# suazo-jara 	 score: 70 	attempts: 41 	total_time: 103
# thetonijua 	 score: 10 	attempts: 2 	total_time: 0
# TioPanxo 	 score: 10 	attempts: 2 	total_time: 0
# UnaCuentaFalsaMas 	 score: 70 	attempts: 7 	total_time: 51
# vicho-bece 	 score: 60 	attempts: 31 	total_time: 137
# XTrAnE 	 score: 10 	attempts: 2 	total_time: 0
